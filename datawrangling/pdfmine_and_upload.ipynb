# %%
import re
import os
import uuid
import json
from pathlib import Path
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTChar, LTImage, LTFigure, LAParams
from pdfminer.converter import PDFPageAggregator
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage

# %%
# Rensning af tekst
to_be_removed = ["ͳ", "•", "→", "□", "▪", "►", "�", "", "", "", ""]
to_be_replaced = {
    "½": "1/2", "–": "-", "‘": "'", "’": "'", "…": "...", "₋": "-", "−": "-",
    "⓫": "11.", "⓬": "12.", "⓭": "13.", "⓮": "14.", "◦": "°",
    "❶": "1.", "❷": "2.", "❸": "3.", "❹": "4.", "❺": "5.",
    "❻": "6.", "❼": "7.", "❽": "8.", "❾": "9.", "❿": "10.",
    "\n": " ",
}

def clean(text):
    for char in to_be_removed:
        text = text.replace(char, "")
    for char, replacement in to_be_replaced.items():
        text = text.replace(char, replacement)
    text = re.sub(r"([a-zà-öø-ÿ])([A-ZÀ-ÖØ-Þ])", r"\1 \2", text)
    text = text.replace(" ,", ",").replace(" .", ".")
    return re.sub(r"\s{2,}", " ", text)

def save_image(image_stream, image_folder):
    image_id = str(uuid.uuid4())
    image_path = os.path.join(image_folder, f"{image_id}.png")
    with open(image_path, 'wb') as f:
        f.write(image_stream)
    return image_id

def find_images(layout_obj):
    """Rekursivt find billeder i layout (også inde i LTFigure)."""
    images = []
    if isinstance(layout_obj, LTImage):
        images.append(layout_obj)
    elif hasattr(layout_obj, "_objs"):
        for obj in layout_obj._objs:
            images.extend(find_images(obj))
    return images

def extract_page_data(path, output_folder, min_font_size=12, footer_font_threshold=10,
                      header_footer_zone=0.8, bottom_footer_zone=0.2):

    filename = os.path.basename(path)
    base_name = os.path.splitext(filename)[0]
    image_output_folder = os.path.join(output_folder, "images", base_name)


    os.makedirs(image_output_folder, exist_ok=True)
    pages_json = []
    last_title = None
    


    with open(path, 'rb') as f:
        for page_number, page in enumerate(PDFPage.get_pages(f), start=1):
            resource_manager = PDFResourceManager()
            laparams = LAParams()
            device = PDFPageAggregator(resource_manager, laparams=laparams)
            interpreter = PDFPageInterpreter(resource_manager, device)
            interpreter.process_page(page)
            layout = device.get_result()

            page_width = layout.width
            page_height = layout.height

            elements = []
            image_ids = []

            for element in layout:
                # Tekst
                if isinstance(element, LTTextContainer):
                    for text_line in element:
                        line_text = text_line.get_text().strip()
                        if not line_text:
                            continue
                        font_sizes = [char.size for char in text_line if isinstance(char, LTChar)]
                        avg_size = sum(font_sizes) / len(font_sizes) if font_sizes else 0
                        x0, y0, x1, y1 = text_line.bbox
                        elements.append((y1, "text", avg_size, line_text, y0, y1))

                # Billeder (rekursivt)
                for img in find_images(element):
                    try:
                        stream = img.stream.get_rawdata()
                        image_id = save_image(stream, image_output_folder)
                        image_tag = f"<image-{image_id}>"
                        image_ids.append(image_id)
                        y0, y1 = img.bbox[1], img.bbox[3]
                        elements.append((y1, "image", 0, image_tag, y0, y1))
                    except Exception as e:
                        print(f"Kunne ikke gemme billede på side {page_number}: {e}")

            elements.sort(reverse=True, key=lambda x: x[0])

            main_lines = []
            footer_top_lines = []
            footer_bottom_lines = []

            # Titel
            title_candidates = [e for e in elements if e[1] == "text" and e[2] >= min_font_size]
            if title_candidates:
                title_element = max(title_candidates, key=lambda x: x[2])
                title = title_element[3]
                last_title = title
            else:
                title = last_title or "Untitled"
                title_element = None

            for elem in elements:
                y1, kind, size, content, y0, _ = elem
                if kind == "image":
                    main_lines.append(content)
                elif title_element and elem == title_element:
                    continue
                elif size >= footer_font_threshold:
                    main_lines.append(content)
                else:
                    if y1 >= page_height * header_footer_zone:
                        footer_top_lines.append(content)
                    elif y1 <= page_height * bottom_footer_zone:
                        footer_bottom_lines.append(content)
                    else:
                        main_lines.append(content)

            raw_text_with_tags = clean(" ".join(main_lines))
            text_for_embedding = re.sub(r"<image-[^>]+>", "", raw_text_with_tags).strip()
            footer_top = clean(" ".join(footer_top_lines))
            footer_bottom = clean(" ".join(footer_bottom_lines))

            if footer_bottom:
                section_name = footer_bottom[:-7].strip()
                page_str = footer_bottom.split()[-1].strip()
            else:
                section_name = ""
                page_str = str(page_number)

            same_exact = (text_for_embedding.strip() == title.strip())
            almost_same = (
                len(text_for_embedding.strip()) <= len(title.strip()) + 10
                and text_for_embedding.strip().startswith(title.strip())
            )
            if same_exact or almost_same:
                continue

            pages_json.append({
                "id": str(uuid.uuid4()),
                "source_file": filename,
                "client": filename[:-4],
                "page_number": page_number,
                "section_name": section_name,
                "title": title,
                "text_for_embedding": f"Section: {section_name}\nTitle: {title}\n\n{text_for_embedding}",
                "raw_text_with_tags": raw_text_with_tags,
                "image_ids": image_ids,
                "footer_top": footer_top
            })

    return pages_json

#Behandlingsfunktion for mappe
def process_folder(folder_path: str, output_dir: str = None, min_font_size: int = 19):
    """
    Behandler alle PDF-filer i folder_path og gemmer hver side som en selvstændig JSON-fil.
    Eksempel: "mailguide_p3.json"
    
    :param folder_path: Sti til mappen med PDF-filer.
    :param output_dir: (Valgfri) Output-mappe. Hvis None, bruges "./output".
    :param min_font_size: Fontstørrelse til extract_page_data.
    """
    folder = Path(folder_path)
    if not folder.is_dir():
        raise ValueError(f"{folder_path} er ikke en gyldig mappe")

    output_folder = Path(output_dir) if output_dir else Path("./output")
    output_folder.mkdir(parents=True, exist_ok=True)

    for pdf_file in folder.glob("*.pdf"):
        try:
            print(f"Behandler: {pdf_file.name}")
            pages_json = extract_page_data(str(pdf_file), output_folder, min_font_size=min_font_size)

            for page in pages_json:
                page_num = page.get("page_number", "NA")
                json_filename = f"{pdf_file.stem}_p{page_num}.json"
                output_path = output_folder / json_filename

                with open(output_path, "w", encoding="utf-8") as f:
                    json.dump(page, f, ensure_ascii=False, indent=2)

            print(f"Gemte {len(pages_json)} sider fra {pdf_file.name} som enkeltfiler.")

        except Exception as e:
            print(f"Fejl ved behandling af {pdf_file.name}: {e}")

# %%
output_dir = "./billede_test0707"
process_folder("./knowledgebase", output_dir)  #"./knowledgebase", "./json_output3")

# - outputdir
#  - - json 1
#  - - json 2 
#  - - image_folder

# %% [markdown]
# Uploader til cosmosDB

# %%
from azure.cosmos import CosmosClient, PartitionKey

# %%
# Cosmos DB adgang
COSMOS_ENDPOINT = "https://valeur-rag-cosmosdb.documents.azure.com:443/"
COSMOS_KEY = "YWjgvfmqFb2VOQSeSuXZ8bIRC5BuIcokcwTIBKezyQM94USh4jolCRNhgB4swz6gxEWNtDLb3NtZACDb3p9gzA=="
DATABASE_NAME = "knowledgebase_db"
CONTAINER_NAME = "kb_container"
PARTITION_KEY_FIELD = "/source_file"

# Forbind til Cosmos DB
client = CosmosClient(COSMOS_ENDPOINT, COSMOS_KEY)
db = client.get_database_client(DATABASE_NAME)
container = db.get_container_client(CONTAINER_NAME)

# %%
# Upload alle .json-filer i mappe
VECTOR_DIR = Path(output_dir)
for path in VECTOR_DIR.glob("*.json"):
    with open(path, "r", encoding="utf-8") as f:
        doc = json.load(f)

    # Partition key check
    pk = doc.get("source_file")
    if not isinstance(pk, str) or not pk.strip():
        print(f"❌ Ugyldig partition key i: {path.name}")
        continue

    # id-felt check
    if "id" not in doc or not isinstance(doc["id"], str) or not doc["id"].strip():
        doc["id"] = path.stem  # Unikt id baseret på filnavn

    try:
        # test serialisering – fanger fx datetime
        json.dumps(doc)

        print(f"🔍 {path.name} - source_file = {pk}, id = {doc['id']}")
        container.upsert_item(doc)
        print(f"✅ Uploaded: {path.name}")
    except Exception as e:
        print(f"❌ Fejl ved {path.name}: {e}")
        print(json.dumps(doc, indent=2))
        break
    finally:
        print("🚀 Upload forsøg færdig")
print("done")
# Out:
# 🔍 Airtox_p1.json - source_file = Airtox.pdf, id = f7e03f24-b9ec-41b8-9fc4-252ad71fdca7
# ✅ Uploaded: Airtox_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p10.json - source_file = Airtox.pdf, id = f02f19d9-3165-4fd3-863f-a58450dc8261
# ✅ Uploaded: Airtox_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p11.json - source_file = Airtox.pdf, id = 67d231a3-02d6-4266-a5cd-1f5f215d961d
# ✅ Uploaded: Airtox_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p12.json - source_file = Airtox.pdf, id = fda46e25-e851-403f-b11c-49300b44b5e7
# ✅ Uploaded: Airtox_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p13.json - source_file = Airtox.pdf, id = f0fecb81-224e-41eb-a9f9-e3d019afdb4b
# ✅ Uploaded: Airtox_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p14.json - source_file = Airtox.pdf, id = 3405e42c-bddf-429b-959f-45be56057010
# ✅ Uploaded: Airtox_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p15.json - source_file = Airtox.pdf, id = 7d77e5b3-96d1-4596-b481-4de2aa2c913c
# ✅ Uploaded: Airtox_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p2.json - source_file = Airtox.pdf, id = adee69b4-9945-4494-988c-3118cbdbbdc0
# ✅ Uploaded: Airtox_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p3.json - source_file = Airtox.pdf, id = a2c4b27b-1fd5-4e4b-95ff-89b106a68984
# ✅ Uploaded: Airtox_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p4.json - source_file = Airtox.pdf, id = 76b40d30-446c-4372-be67-35cebd44909d
# ✅ Uploaded: Airtox_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p5.json - source_file = Airtox.pdf, id = b9832894-bace-42d8-b35d-1f2473358aea
# ✅ Uploaded: Airtox_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p6.json - source_file = Airtox.pdf, id = 2ca73956-3e04-48a6-8a19-0559c16532ea
# ✅ Uploaded: Airtox_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p7.json - source_file = Airtox.pdf, id = 41d7552a-2971-4e13-9724-fd91337ee8a8
# ✅ Uploaded: Airtox_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p8.json - source_file = Airtox.pdf, id = 2428958c-19e5-477a-ac67-304a6ef1ac42
# ✅ Uploaded: Airtox_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Airtox_p9.json - source_file = Airtox.pdf, id = a82e849c-8f36-43ee-b529-38031050a86b
# ✅ Uploaded: Airtox_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p1.json - source_file = Barons.pdf, id = 58e278b9-501d-4a8b-9a06-1e016f69fcee
# ✅ Uploaded: Barons_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p10.json - source_file = Barons.pdf, id = 30e56dad-5f55-481f-b4b4-fcbf033d7c61
# ✅ Uploaded: Barons_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p11.json - source_file = Barons.pdf, id = 951dd3ac-8db4-4f00-8ef7-0c48b285d3c3
# ✅ Uploaded: Barons_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p12.json - source_file = Barons.pdf, id = c4d16cf5-7312-42ea-b358-063169e0b740
# ✅ Uploaded: Barons_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p13.json - source_file = Barons.pdf, id = d02013f2-6954-4c7a-a024-8aaae15c22ff
# ✅ Uploaded: Barons_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p14.json - source_file = Barons.pdf, id = 9268745c-8a72-42d4-8842-8959e0f0d456
# ✅ Uploaded: Barons_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p15.json - source_file = Barons.pdf, id = ba8735ba-154c-49fc-8439-b747864bbc3f
# ✅ Uploaded: Barons_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p16.json - source_file = Barons.pdf, id = 41cc46bb-6d66-4d08-bbed-5b43b33c0876
# ✅ Uploaded: Barons_p16.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p17.json - source_file = Barons.pdf, id = 93bb1097-3e8b-4b33-abb7-1da09c473daf
# ✅ Uploaded: Barons_p17.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p18.json - source_file = Barons.pdf, id = c944442b-f1d8-4c25-88d3-3f04ff51a4e9
# ✅ Uploaded: Barons_p18.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p19.json - source_file = Barons.pdf, id = 82118661-7399-425a-b2af-1f7366832462
# ✅ Uploaded: Barons_p19.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p2.json - source_file = Barons.pdf, id = 1d393e66-711c-458f-b321-19fa303e83b7
# ✅ Uploaded: Barons_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p20.json - source_file = Barons.pdf, id = bce22f25-00f1-4338-b8c5-1283a8e6cb1b
# ✅ Uploaded: Barons_p20.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p21.json - source_file = Barons.pdf, id = af64cb58-c381-4f4f-b0cc-f36b5acf4dc0
# ✅ Uploaded: Barons_p21.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p22.json - source_file = Barons.pdf, id = e255b7fe-ae0d-4d4b-8863-5af67f5a9779
# ✅ Uploaded: Barons_p22.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p23.json - source_file = Barons.pdf, id = b365c088-2f9f-40ce-8f97-9a17fa9b8b0d
# ✅ Uploaded: Barons_p23.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p24.json - source_file = Barons.pdf, id = 5dadbf4c-5b47-4df1-9e5e-7b425731e0c7
# ✅ Uploaded: Barons_p24.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p25.json - source_file = Barons.pdf, id = 12061c2d-9403-4a06-9a18-f1e67b959663
# ✅ Uploaded: Barons_p25.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p26.json - source_file = Barons.pdf, id = d1850a96-3539-4cf8-9353-57d6e1a6fb57
# ✅ Uploaded: Barons_p26.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p27.json - source_file = Barons.pdf, id = c8c22b3f-a882-4e12-add1-3a1afc3a3065
# ✅ Uploaded: Barons_p27.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p28.json - source_file = Barons.pdf, id = e8404e8e-891e-4105-bd50-fe9969a4cddf
# ✅ Uploaded: Barons_p28.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p29.json - source_file = Barons.pdf, id = 2a99b565-0f2e-4609-bbe5-c911af1b43fd
# ✅ Uploaded: Barons_p29.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p3.json - source_file = Barons.pdf, id = 212b4a19-cc14-4df0-bc29-aac2bfa622a7
# ✅ Uploaded: Barons_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p30.json - source_file = Barons.pdf, id = 7d0ab9b9-a79d-46d7-9042-458264988c69
# ✅ Uploaded: Barons_p30.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p31.json - source_file = Barons.pdf, id = 815d9ced-9444-4a21-b868-04c00d82033b
# ✅ Uploaded: Barons_p31.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p32.json - source_file = Barons.pdf, id = 67bfd42b-6df9-467b-9211-ccc3aefbd7ca
# ✅ Uploaded: Barons_p32.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p33.json - source_file = Barons.pdf, id = 98a938ee-5e65-4e30-a03a-8b7af9daa7e2
# ✅ Uploaded: Barons_p33.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p34.json - source_file = Barons.pdf, id = 10e9fc44-479f-4f58-89a4-5565b0f5fe8b
# ✅ Uploaded: Barons_p34.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p35.json - source_file = Barons.pdf, id = 878d6406-2fa9-4440-954e-260e5dbd8c24
# ✅ Uploaded: Barons_p35.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p36.json - source_file = Barons.pdf, id = 3bff00bd-eaa1-4e34-8bdf-c3ee0b73b28a
# ✅ Uploaded: Barons_p36.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p37.json - source_file = Barons.pdf, id = 52a2be09-6f66-44ba-87e4-1cb5ba92294f
# ✅ Uploaded: Barons_p37.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p38.json - source_file = Barons.pdf, id = bd36665b-f9e2-4b03-bfc1-d0ff738871d2
# ✅ Uploaded: Barons_p38.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p39.json - source_file = Barons.pdf, id = 397b65a5-76f6-4203-a188-a40bb4ece25f
# ✅ Uploaded: Barons_p39.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p4.json - source_file = Barons.pdf, id = b2ad9430-7d0b-4de3-8797-a80200badac5
# ✅ Uploaded: Barons_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p40.json - source_file = Barons.pdf, id = 9b25cac7-f3a2-4b4c-9285-61c0ba1cc1a6
# ✅ Uploaded: Barons_p40.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p41.json - source_file = Barons.pdf, id = 6f7d898c-9a13-4b63-aded-7eeddda163c1
# ✅ Uploaded: Barons_p41.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p42.json - source_file = Barons.pdf, id = f2f803f8-c15e-49c9-bc6e-674e16eca20e
# ✅ Uploaded: Barons_p42.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p43.json - source_file = Barons.pdf, id = c6a66170-b78c-44da-b18f-adecc322e98e
# ✅ Uploaded: Barons_p43.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p44.json - source_file = Barons.pdf, id = 1fb2b044-5940-40bf-8699-76fb9c7e951e
# ✅ Uploaded: Barons_p44.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p45.json - source_file = Barons.pdf, id = 8cf3718f-4a02-4b92-892b-5b3971a4e879
# ✅ Uploaded: Barons_p45.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p46.json - source_file = Barons.pdf, id = 82525e21-518d-41d2-bd3a-df62f9260347
# ✅ Uploaded: Barons_p46.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p47.json - source_file = Barons.pdf, id = fb3ce53c-6ed5-4ba1-9056-af246603cea8
# ✅ Uploaded: Barons_p47.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p48.json - source_file = Barons.pdf, id = bf614f94-ac32-425d-92a1-5d33caf17b01
# ✅ Uploaded: Barons_p48.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p49.json - source_file = Barons.pdf, id = cf1c08b0-6307-4b08-a17b-06d787e946b9
# ✅ Uploaded: Barons_p49.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p5.json - source_file = Barons.pdf, id = c36f633b-65ab-48f2-afb6-a14330ce4056
# ✅ Uploaded: Barons_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p50.json - source_file = Barons.pdf, id = 24320908-e13e-4d42-bdb7-8f7928b7aec4
# ✅ Uploaded: Barons_p50.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p51.json - source_file = Barons.pdf, id = 4585fc56-9b2a-46fb-a0f2-38e55be1f5af
# ✅ Uploaded: Barons_p51.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p52.json - source_file = Barons.pdf, id = f9fe72d8-94db-41bf-977e-8c989d10a413
# ✅ Uploaded: Barons_p52.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p53.json - source_file = Barons.pdf, id = a565bea4-dff1-4bd9-ae7c-3c7282c6efb0
# ✅ Uploaded: Barons_p53.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p54.json - source_file = Barons.pdf, id = 8af226d8-513f-426a-a09f-8e566e43cb0a
# ✅ Uploaded: Barons_p54.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p55.json - source_file = Barons.pdf, id = f846594f-a6d6-4502-8496-a75eef8e5161
# ✅ Uploaded: Barons_p55.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p56.json - source_file = Barons.pdf, id = 5472f458-b110-4e6e-a552-18abca42ad35
# ✅ Uploaded: Barons_p56.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p57.json - source_file = Barons.pdf, id = be89dc61-926a-45f5-9472-6ea136b1ef13
# ✅ Uploaded: Barons_p57.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p58.json - source_file = Barons.pdf, id = bba7aad4-6334-4e91-a23e-01f8dc750616
# ✅ Uploaded: Barons_p58.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p59.json - source_file = Barons.pdf, id = a2c04ee4-ce9f-4211-86d0-3f7e89c5c074
# ✅ Uploaded: Barons_p59.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p6.json - source_file = Barons.pdf, id = bd060faf-9361-4f68-af5e-e85e22e831f5
# ✅ Uploaded: Barons_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p60.json - source_file = Barons.pdf, id = b825f3e6-496d-4526-aa7d-ea833d80b23e
# ✅ Uploaded: Barons_p60.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p61.json - source_file = Barons.pdf, id = bb9bcd4b-ae48-4092-8547-c6614fd6b12d
# ✅ Uploaded: Barons_p61.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p62.json - source_file = Barons.pdf, id = 58ee96e0-91bb-4dd2-b123-dffa8da59402
# ✅ Uploaded: Barons_p62.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p63.json - source_file = Barons.pdf, id = cb2c6b80-75ed-4557-a2d6-5314435f5b09
# ✅ Uploaded: Barons_p63.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p64.json - source_file = Barons.pdf, id = 1de45c7e-b665-4378-8fdf-edeb926b628d
# ✅ Uploaded: Barons_p64.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p65.json - source_file = Barons.pdf, id = ec9e6eb0-3684-4cdd-a0f2-2b645fdeda87
# ✅ Uploaded: Barons_p65.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p66.json - source_file = Barons.pdf, id = 0f0fab55-3fa5-41c3-862d-ff24aa575323
# ✅ Uploaded: Barons_p66.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p67.json - source_file = Barons.pdf, id = 33089f74-b1eb-4ef7-8a5c-7270761af225
# ✅ Uploaded: Barons_p67.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p68.json - source_file = Barons.pdf, id = 2ea01f87-1de6-456c-abe1-61210d9dd885
# ✅ Uploaded: Barons_p68.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p69.json - source_file = Barons.pdf, id = 28caa229-2009-4a92-9d7d-e030f78d12c4
# ✅ Uploaded: Barons_p69.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p7.json - source_file = Barons.pdf, id = 677cb2e2-857e-4aea-91c8-6fc360ac580e
# ✅ Uploaded: Barons_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p70.json - source_file = Barons.pdf, id = bd7fe456-d76b-431e-8c76-32b0fe37f28a
# ✅ Uploaded: Barons_p70.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p71.json - source_file = Barons.pdf, id = 55e4a6a8-2c01-47d1-9f3d-4d8cc2ad2fdf
# ✅ Uploaded: Barons_p71.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p72.json - source_file = Barons.pdf, id = d4466919-2ce1-4981-9e04-2a1ed5f097e5
# ✅ Uploaded: Barons_p72.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p73.json - source_file = Barons.pdf, id = 2f9614a1-bd4a-4335-ab1c-52145d2173db
# ✅ Uploaded: Barons_p73.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p74.json - source_file = Barons.pdf, id = a5462e6d-d119-4f4f-abdc-b238ec7f7f78
# ✅ Uploaded: Barons_p74.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p75.json - source_file = Barons.pdf, id = c8857fa4-d7a4-43c5-a41b-3ce369025561
# ✅ Uploaded: Barons_p75.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p76.json - source_file = Barons.pdf, id = badf2cfa-2a79-41ff-aeb5-e1df22f23acb
# ✅ Uploaded: Barons_p76.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p77.json - source_file = Barons.pdf, id = 7962a3d3-d0b8-4348-9b4b-d47a89140dbd
# ✅ Uploaded: Barons_p77.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p78.json - source_file = Barons.pdf, id = c4c0ef63-56df-490e-b975-962cd3d95467
# ✅ Uploaded: Barons_p78.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p79.json - source_file = Barons.pdf, id = ab7b5f8f-5883-4f8d-a737-4743e7dbdc8d
# ✅ Uploaded: Barons_p79.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p8.json - source_file = Barons.pdf, id = 1fe253d8-40f3-425b-9e12-ed750f77435a
# ✅ Uploaded: Barons_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p80.json - source_file = Barons.pdf, id = a9532013-86b1-432c-b5f2-c869597db680
# ✅ Uploaded: Barons_p80.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p81.json - source_file = Barons.pdf, id = cc6d1a6f-554e-40ca-8d14-f0ba1aa69e8c
# ✅ Uploaded: Barons_p81.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p82.json - source_file = Barons.pdf, id = 254e3dfc-26c6-40f0-8de4-7e19cd1abbbf
# ✅ Uploaded: Barons_p82.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p83.json - source_file = Barons.pdf, id = 727596fd-1ed6-42d5-bb7f-296888c04220
# ✅ Uploaded: Barons_p83.json
# 🚀 Upload forsøg færdig
# 🔍 Barons_p9.json - source_file = Barons.pdf, id = 5523c13b-869f-4e9e-a611-3927a6ac5773
# ✅ Uploaded: Barons_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p1.json - source_file = Billund Lufthavn.pdf, id = 0d1c3d27-9466-4348-913e-5d107eafd8a9
# ✅ Uploaded: Billund Lufthavn_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p10.json - source_file = Billund Lufthavn.pdf, id = 0d509da0-0d49-488a-9956-40847e71fdbd
# ✅ Uploaded: Billund Lufthavn_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p11.json - source_file = Billund Lufthavn.pdf, id = d1856bbf-03af-4142-b341-8d154c2cd73c
# ✅ Uploaded: Billund Lufthavn_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p12.json - source_file = Billund Lufthavn.pdf, id = 302f0d64-8d96-47f9-843e-0b93873860a7
# ✅ Uploaded: Billund Lufthavn_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p13.json - source_file = Billund Lufthavn.pdf, id = e2ed6fcb-777f-46f7-8b9b-0fd82247fa3e
# ✅ Uploaded: Billund Lufthavn_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p14.json - source_file = Billund Lufthavn.pdf, id = bfd8469d-1e1e-4fbd-a40a-6b809e029d0c
# ✅ Uploaded: Billund Lufthavn_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p15.json - source_file = Billund Lufthavn.pdf, id = 6d1d1e7b-ed43-4c0d-b3f2-f536fa9579dc
# ✅ Uploaded: Billund Lufthavn_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p16.json - source_file = Billund Lufthavn.pdf, id = 98c73578-0b9b-47b7-893c-578d4be23bef
# ✅ Uploaded: Billund Lufthavn_p16.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p17.json - source_file = Billund Lufthavn.pdf, id = af85411a-4f8c-46de-9751-bbbfdfc5cc5b
# ✅ Uploaded: Billund Lufthavn_p17.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p18.json - source_file = Billund Lufthavn.pdf, id = 93d8d3f2-941a-4ebb-84a0-872bc6fe5e73
# ✅ Uploaded: Billund Lufthavn_p18.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p19.json - source_file = Billund Lufthavn.pdf, id = 68c9e32c-4335-4e6b-b312-790644bf6baf
# ✅ Uploaded: Billund Lufthavn_p19.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p2.json - source_file = Billund Lufthavn.pdf, id = 37642f58-9396-4f4f-b18e-af217a0cfd1e
# ✅ Uploaded: Billund Lufthavn_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p20.json - source_file = Billund Lufthavn.pdf, id = 5b6d251a-b2d3-46b1-8bd0-dbac8a5f33cc
# ✅ Uploaded: Billund Lufthavn_p20.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p21.json - source_file = Billund Lufthavn.pdf, id = 86d09b51-ae6a-417f-a3d5-4c7615c97541
# ✅ Uploaded: Billund Lufthavn_p21.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p22.json - source_file = Billund Lufthavn.pdf, id = d934b405-f1d7-4bea-baaf-e2542c4090fb
# ✅ Uploaded: Billund Lufthavn_p22.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p23.json - source_file = Billund Lufthavn.pdf, id = 67a2168a-313e-40f4-8005-7a742b7cabe0
# ✅ Uploaded: Billund Lufthavn_p23.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p24.json - source_file = Billund Lufthavn.pdf, id = b5335df0-66e2-4679-b819-14ecbc867036
# ✅ Uploaded: Billund Lufthavn_p24.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p25.json - source_file = Billund Lufthavn.pdf, id = a220e183-788a-4ed1-9cda-22e2865d9aa3
# ✅ Uploaded: Billund Lufthavn_p25.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p26.json - source_file = Billund Lufthavn.pdf, id = cab7a2fb-6493-474e-b24a-7f5cf617e5cd
# ✅ Uploaded: Billund Lufthavn_p26.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p27.json - source_file = Billund Lufthavn.pdf, id = 66a4a6f2-8cbf-45f0-ba73-f3e9a322cf34
# ✅ Uploaded: Billund Lufthavn_p27.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p28.json - source_file = Billund Lufthavn.pdf, id = 5d03a3b0-7dce-4a75-9bf2-f06334bc595c
# ✅ Uploaded: Billund Lufthavn_p28.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p29.json - source_file = Billund Lufthavn.pdf, id = 3e67c7f7-25a5-4c9b-ad9c-4feaa268aac0
# ✅ Uploaded: Billund Lufthavn_p29.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p3.json - source_file = Billund Lufthavn.pdf, id = 5b530334-c1a3-497c-a3b5-93cc5a9cbd2f
# ✅ Uploaded: Billund Lufthavn_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p30.json - source_file = Billund Lufthavn.pdf, id = 57f2c3bc-5392-49bd-86e3-7d4211cc08af
# ✅ Uploaded: Billund Lufthavn_p30.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p31.json - source_file = Billund Lufthavn.pdf, id = 73721fca-141c-4042-a649-bf4d77f9cf73
# ✅ Uploaded: Billund Lufthavn_p31.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p32.json - source_file = Billund Lufthavn.pdf, id = bd5ebadd-5860-4a79-a731-3a005a90e263
# ✅ Uploaded: Billund Lufthavn_p32.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p33.json - source_file = Billund Lufthavn.pdf, id = 35558ccb-e312-4c1d-929b-51c2aadd3dbf
# ✅ Uploaded: Billund Lufthavn_p33.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p34.json - source_file = Billund Lufthavn.pdf, id = b7fdff4c-015d-4485-ae15-503375c1d507
# ✅ Uploaded: Billund Lufthavn_p34.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p35.json - source_file = Billund Lufthavn.pdf, id = f58a9ca5-f2ce-4c42-834d-03f5ec8e0720
# ✅ Uploaded: Billund Lufthavn_p35.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p36.json - source_file = Billund Lufthavn.pdf, id = 70913c81-a703-4216-ae69-79f861a8abd1
# ✅ Uploaded: Billund Lufthavn_p36.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p37.json - source_file = Billund Lufthavn.pdf, id = f357c5f6-55f2-4191-aad9-a70c19330ca1
# ✅ Uploaded: Billund Lufthavn_p37.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p38.json - source_file = Billund Lufthavn.pdf, id = 1497bbd2-da61-48c0-aa94-a33e9aa22ce5
# ✅ Uploaded: Billund Lufthavn_p38.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p39.json - source_file = Billund Lufthavn.pdf, id = 7538a1b4-3629-42c2-afd1-cdb5ffafc672
# ✅ Uploaded: Billund Lufthavn_p39.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p4.json - source_file = Billund Lufthavn.pdf, id = f459108d-7eb0-4e39-89f1-252ffe3eeead
# ✅ Uploaded: Billund Lufthavn_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p40.json - source_file = Billund Lufthavn.pdf, id = cfdda7ae-210f-4297-afdc-93bdbd79fc08
# ✅ Uploaded: Billund Lufthavn_p40.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p41.json - source_file = Billund Lufthavn.pdf, id = 4766b805-3cba-459d-9a37-e8bec21593b6
# ✅ Uploaded: Billund Lufthavn_p41.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p42.json - source_file = Billund Lufthavn.pdf, id = 68030a9e-c7af-4a67-ad2b-ac1de737e9ac
# ✅ Uploaded: Billund Lufthavn_p42.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p43.json - source_file = Billund Lufthavn.pdf, id = 03790dcb-ab42-46eb-bf84-619cd644dc47
# ✅ Uploaded: Billund Lufthavn_p43.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p44.json - source_file = Billund Lufthavn.pdf, id = 63ee52e9-1fd0-4f16-a0fc-8f9eb0eff268
# ✅ Uploaded: Billund Lufthavn_p44.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p45.json - source_file = Billund Lufthavn.pdf, id = 860d447e-9bcf-458b-bdf2-9303053fa45a
# ✅ Uploaded: Billund Lufthavn_p45.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p46.json - source_file = Billund Lufthavn.pdf, id = 12c5f100-abaa-4958-a154-31b2f2271325
# ✅ Uploaded: Billund Lufthavn_p46.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p47.json - source_file = Billund Lufthavn.pdf, id = 9ce9e627-a377-4941-81a1-112d932855a4
# ✅ Uploaded: Billund Lufthavn_p47.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p48.json - source_file = Billund Lufthavn.pdf, id = e7c2f5ab-222c-4aaf-aeab-ff6adba04fc9
# ✅ Uploaded: Billund Lufthavn_p48.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p49.json - source_file = Billund Lufthavn.pdf, id = 65400397-06c4-4763-bbdc-e5991bae2e98
# ✅ Uploaded: Billund Lufthavn_p49.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p5.json - source_file = Billund Lufthavn.pdf, id = 145e0d86-7ddd-4e43-b5f2-ca4cae1c659b
# ✅ Uploaded: Billund Lufthavn_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p50.json - source_file = Billund Lufthavn.pdf, id = f4fbc1f5-5e7b-4cab-b15c-e7683f8cab32
# ✅ Uploaded: Billund Lufthavn_p50.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p51.json - source_file = Billund Lufthavn.pdf, id = 22859bd2-2660-4cc6-9e3b-9a9b79477d09
# ✅ Uploaded: Billund Lufthavn_p51.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p52.json - source_file = Billund Lufthavn.pdf, id = 0b81c250-20fc-4a85-844c-420472759aac
# ✅ Uploaded: Billund Lufthavn_p52.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p53.json - source_file = Billund Lufthavn.pdf, id = f3518953-9ffc-45bb-a70c-6e7d048bd1f4
# ✅ Uploaded: Billund Lufthavn_p53.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p54.json - source_file = Billund Lufthavn.pdf, id = 5b8b28e9-a7ad-4048-a741-d281b1beb85f
# ✅ Uploaded: Billund Lufthavn_p54.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p55.json - source_file = Billund Lufthavn.pdf, id = 0cd860ee-c610-4ee8-ab83-94f6d74618b6
# ✅ Uploaded: Billund Lufthavn_p55.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p56.json - source_file = Billund Lufthavn.pdf, id = 1a99a3ef-6e1c-423a-aa3c-24eb3e25f46a
# ✅ Uploaded: Billund Lufthavn_p56.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p57.json - source_file = Billund Lufthavn.pdf, id = 367915dd-8bbf-4923-8a0c-d6d2de6ba89b
# ✅ Uploaded: Billund Lufthavn_p57.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p58.json - source_file = Billund Lufthavn.pdf, id = df11e10e-f062-4462-aa8f-dc4a5562818f
# ✅ Uploaded: Billund Lufthavn_p58.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p59.json - source_file = Billund Lufthavn.pdf, id = cd45b070-6eb5-4386-954f-9f634536457c
# ✅ Uploaded: Billund Lufthavn_p59.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p6.json - source_file = Billund Lufthavn.pdf, id = 6199f4b8-c626-4fbc-b25b-5a455cde6430
# ✅ Uploaded: Billund Lufthavn_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p60.json - source_file = Billund Lufthavn.pdf, id = 873c9b85-cffd-4b7f-b16f-47be69466fb6
# ✅ Uploaded: Billund Lufthavn_p60.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p61.json - source_file = Billund Lufthavn.pdf, id = 5b80710b-1c57-41ee-b482-f0967d894dda
# ✅ Uploaded: Billund Lufthavn_p61.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p62.json - source_file = Billund Lufthavn.pdf, id = 6e947cdf-407c-43ba-9070-f2ff4d3d0c17
# ✅ Uploaded: Billund Lufthavn_p62.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p63.json - source_file = Billund Lufthavn.pdf, id = 701a5953-e96c-4be5-b7d8-e03862ed623f
# ✅ Uploaded: Billund Lufthavn_p63.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p64.json - source_file = Billund Lufthavn.pdf, id = ad291a38-32d4-4fcb-bded-9b59f4d02861
# ✅ Uploaded: Billund Lufthavn_p64.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p65.json - source_file = Billund Lufthavn.pdf, id = d9a3f43c-9c94-4ec3-abae-efe6a4684305
# ✅ Uploaded: Billund Lufthavn_p65.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p66.json - source_file = Billund Lufthavn.pdf, id = 88c74408-903f-4d83-9e6d-24dc3fca19f0
# ✅ Uploaded: Billund Lufthavn_p66.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p67.json - source_file = Billund Lufthavn.pdf, id = 424d4bac-e51a-4c56-9d08-acfae8862e10
# ✅ Uploaded: Billund Lufthavn_p67.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p68.json - source_file = Billund Lufthavn.pdf, id = 98d801b6-5f8d-47e3-9e62-632244234572
# ✅ Uploaded: Billund Lufthavn_p68.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p69.json - source_file = Billund Lufthavn.pdf, id = ec69718b-a501-4789-9bd0-06a895264a93
# ✅ Uploaded: Billund Lufthavn_p69.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p7.json - source_file = Billund Lufthavn.pdf, id = 1abce2d4-d7bc-4737-848d-2ccbec6b410e
# ✅ Uploaded: Billund Lufthavn_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p70.json - source_file = Billund Lufthavn.pdf, id = 5b8582b2-6af6-45e5-b4cc-6a7d40f64266
# ✅ Uploaded: Billund Lufthavn_p70.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p71.json - source_file = Billund Lufthavn.pdf, id = d2bc55e6-397e-484a-a624-52a5f952679b
# ✅ Uploaded: Billund Lufthavn_p71.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p72.json - source_file = Billund Lufthavn.pdf, id = 4a173de6-49c8-4c29-b1d8-6620f977c335
# ✅ Uploaded: Billund Lufthavn_p72.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p73.json - source_file = Billund Lufthavn.pdf, id = 84f4335d-5c90-4989-aef5-60855f8ed2a7
# ✅ Uploaded: Billund Lufthavn_p73.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p74.json - source_file = Billund Lufthavn.pdf, id = 130adb07-ee39-4f9c-9fba-fb69f7adf5fc
# ✅ Uploaded: Billund Lufthavn_p74.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p75.json - source_file = Billund Lufthavn.pdf, id = fbaa8370-ad14-4b48-89c0-a90e24aca5b1
# ✅ Uploaded: Billund Lufthavn_p75.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p76.json - source_file = Billund Lufthavn.pdf, id = 48fb9e57-d08c-4b43-8cfd-7f895cf2ff3b
# ✅ Uploaded: Billund Lufthavn_p76.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p77.json - source_file = Billund Lufthavn.pdf, id = af587a08-0e0e-4d8e-9790-fba784a07254
# ✅ Uploaded: Billund Lufthavn_p77.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p78.json - source_file = Billund Lufthavn.pdf, id = 39af8105-4434-4659-b143-36438405c398
# ✅ Uploaded: Billund Lufthavn_p78.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p79.json - source_file = Billund Lufthavn.pdf, id = 20e53489-7ae9-4b69-bccc-e324a78c11f5
# ✅ Uploaded: Billund Lufthavn_p79.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p8.json - source_file = Billund Lufthavn.pdf, id = 2c7755ee-b206-4543-b1c1-843a3ca78fba
# ✅ Uploaded: Billund Lufthavn_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p80.json - source_file = Billund Lufthavn.pdf, id = 578d4b47-b296-4a72-8c8c-81b96217091e
# ✅ Uploaded: Billund Lufthavn_p80.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p81.json - source_file = Billund Lufthavn.pdf, id = 38cbe1fe-4b5c-404d-9237-172aea8fbcb4
# ✅ Uploaded: Billund Lufthavn_p81.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p82.json - source_file = Billund Lufthavn.pdf, id = 47c7c96d-2c03-469d-8db9-f28c0171f06f
# ✅ Uploaded: Billund Lufthavn_p82.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p83.json - source_file = Billund Lufthavn.pdf, id = 85fb81a3-f5b0-4f8a-b8ce-248987611042
# ✅ Uploaded: Billund Lufthavn_p83.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p84.json - source_file = Billund Lufthavn.pdf, id = 96bf3b10-e250-4708-8555-aee95124e6af
# ✅ Uploaded: Billund Lufthavn_p84.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p85.json - source_file = Billund Lufthavn.pdf, id = a8ae51bb-2689-41fe-96d9-37bf4ba6028e
# ✅ Uploaded: Billund Lufthavn_p85.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p86.json - source_file = Billund Lufthavn.pdf, id = ece8bead-bea7-4e5a-a45d-1df6ccf14db5
# ✅ Uploaded: Billund Lufthavn_p86.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p87.json - source_file = Billund Lufthavn.pdf, id = 1ebef741-5284-419e-8860-c758680f0949
# ✅ Uploaded: Billund Lufthavn_p87.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p88.json - source_file = Billund Lufthavn.pdf, id = b1fe18cb-56b6-427b-9a29-60491c8eb73f
# ✅ Uploaded: Billund Lufthavn_p88.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p89.json - source_file = Billund Lufthavn.pdf, id = 7506e6a0-afb4-406e-b763-42e9fec90c76
# ✅ Uploaded: Billund Lufthavn_p89.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p9.json - source_file = Billund Lufthavn.pdf, id = ce23bd8a-9ffe-4723-bda2-60ae8758fc57
# ✅ Uploaded: Billund Lufthavn_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p90.json - source_file = Billund Lufthavn.pdf, id = fbe7b6cf-bacf-4a07-9d03-0b0a1f6d5318
# ✅ Uploaded: Billund Lufthavn_p90.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p91.json - source_file = Billund Lufthavn.pdf, id = 8e05d111-a216-448c-8f49-536e63dc9f48
# ✅ Uploaded: Billund Lufthavn_p91.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p92.json - source_file = Billund Lufthavn.pdf, id = b375729f-8044-4007-978b-b5eace92953f
# ✅ Uploaded: Billund Lufthavn_p92.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p93.json - source_file = Billund Lufthavn.pdf, id = 0daf8266-3e06-47a7-a77a-ffab7925aa23
# ✅ Uploaded: Billund Lufthavn_p93.json
# 🚀 Upload forsøg færdig
# 🔍 Billund Lufthavn_p94.json - source_file = Billund Lufthavn.pdf, id = cf3f80a0-e61d-4a83-8ffd-21105a720561
# ✅ Uploaded: Billund Lufthavn_p94.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p1.json - source_file = Dansk Psykolog Forening.pdf, id = 3de1cf4a-1175-4bac-980f-5467d1c306ac
# ✅ Uploaded: Dansk Psykolog Forening_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p10.json - source_file = Dansk Psykolog Forening.pdf, id = 0f047e87-81da-4e29-928c-77c7f281bd59
# ✅ Uploaded: Dansk Psykolog Forening_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p11.json - source_file = Dansk Psykolog Forening.pdf, id = 927f64f8-2c0c-4069-9262-9f78c070c3db
# ✅ Uploaded: Dansk Psykolog Forening_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p12.json - source_file = Dansk Psykolog Forening.pdf, id = 297b6896-aee1-4a24-9f9b-8b46c1079706
# ✅ Uploaded: Dansk Psykolog Forening_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p13.json - source_file = Dansk Psykolog Forening.pdf, id = fad91e2b-18bb-46a1-9ced-17c1b75fddb4
# ✅ Uploaded: Dansk Psykolog Forening_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p2.json - source_file = Dansk Psykolog Forening.pdf, id = f9d9d5b3-2f4c-46be-b975-6f11a9823620
# ✅ Uploaded: Dansk Psykolog Forening_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p3.json - source_file = Dansk Psykolog Forening.pdf, id = f057eb23-4a9d-4e8e-a11b-07f0f0808c3c
# ✅ Uploaded: Dansk Psykolog Forening_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p4.json - source_file = Dansk Psykolog Forening.pdf, id = 0f5b2b91-9eaa-47a5-aa24-eac9aa239fb5
# ✅ Uploaded: Dansk Psykolog Forening_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p5.json - source_file = Dansk Psykolog Forening.pdf, id = 70223718-1b6b-41ce-ad6e-ab7bf581b341
# ✅ Uploaded: Dansk Psykolog Forening_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p6.json - source_file = Dansk Psykolog Forening.pdf, id = 16864bbd-e668-4f8d-9a52-ea3382d1a617
# ✅ Uploaded: Dansk Psykolog Forening_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p7.json - source_file = Dansk Psykolog Forening.pdf, id = 9371fc0f-06db-4207-b160-947e6f3580bb
# ✅ Uploaded: Dansk Psykolog Forening_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p8.json - source_file = Dansk Psykolog Forening.pdf, id = f840bdcb-f0e4-4084-91bf-49132279be9c
# ✅ Uploaded: Dansk Psykolog Forening_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Dansk Psykolog Forening_p9.json - source_file = Dansk Psykolog Forening.pdf, id = 18a415b4-447f-4d05-8f27-94f72df9ec4e
# ✅ Uploaded: Dansk Psykolog Forening_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p1.json - source_file = Forbrugsforeningen.pdf, id = 5bfd9cd1-51b2-4fa8-8673-576c6a0eaba5
# ✅ Uploaded: Forbrugsforeningen_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p10.json - source_file = Forbrugsforeningen.pdf, id = 4928079e-7343-482e-a581-4e882e9506b3
# ✅ Uploaded: Forbrugsforeningen_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p11.json - source_file = Forbrugsforeningen.pdf, id = 5c43b24a-31b9-470e-98c6-e2852fe5e3a5
# ✅ Uploaded: Forbrugsforeningen_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p12.json - source_file = Forbrugsforeningen.pdf, id = 83297d13-9aac-46ae-bec8-71d6d197be7a
# ✅ Uploaded: Forbrugsforeningen_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p13.json - source_file = Forbrugsforeningen.pdf, id = 466ed7da-9985-480d-ab68-61aed862324d
# ✅ Uploaded: Forbrugsforeningen_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p14.json - source_file = Forbrugsforeningen.pdf, id = 64ecb6a5-4057-4263-9a27-e5a4277d72e5
# ✅ Uploaded: Forbrugsforeningen_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p15.json - source_file = Forbrugsforeningen.pdf, id = 83e0cf8c-55f8-496b-ad26-7c1a3d7d53a4
# ✅ Uploaded: Forbrugsforeningen_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p16.json - source_file = Forbrugsforeningen.pdf, id = 023698c3-b29a-4082-ba99-4730598e2d53
# ✅ Uploaded: Forbrugsforeningen_p16.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p17.json - source_file = Forbrugsforeningen.pdf, id = 4b49aac0-3368-4c8a-93c0-2ba15789c9fd
# ✅ Uploaded: Forbrugsforeningen_p17.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p18.json - source_file = Forbrugsforeningen.pdf, id = c16e9aa1-13b5-4c20-90b1-81bbc638aaf3
# ✅ Uploaded: Forbrugsforeningen_p18.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p19.json - source_file = Forbrugsforeningen.pdf, id = 61d173a1-27b9-4b99-a9a7-8c5391160491
# ✅ Uploaded: Forbrugsforeningen_p19.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p2.json - source_file = Forbrugsforeningen.pdf, id = 42ac8521-a282-492d-8926-664e963811a8
# ✅ Uploaded: Forbrugsforeningen_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p20.json - source_file = Forbrugsforeningen.pdf, id = 2220a852-e9a7-4c56-ac90-27d7ae69318e
# ✅ Uploaded: Forbrugsforeningen_p20.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p21.json - source_file = Forbrugsforeningen.pdf, id = 43f7b5f6-1134-48ff-a4e6-b11d205f68d7
# ✅ Uploaded: Forbrugsforeningen_p21.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p22.json - source_file = Forbrugsforeningen.pdf, id = 94989784-7a42-4248-aacf-1b7923df611b
# ✅ Uploaded: Forbrugsforeningen_p22.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p23.json - source_file = Forbrugsforeningen.pdf, id = 7c2f06a3-8b17-41f7-a7dc-27812b348b09
# ✅ Uploaded: Forbrugsforeningen_p23.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p24.json - source_file = Forbrugsforeningen.pdf, id = 0f53ac5c-628f-4d04-8eab-52add40cf59e
# ✅ Uploaded: Forbrugsforeningen_p24.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p25.json - source_file = Forbrugsforeningen.pdf, id = bff1186d-2709-4b80-8dd7-ca024030be28
# ✅ Uploaded: Forbrugsforeningen_p25.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p26.json - source_file = Forbrugsforeningen.pdf, id = 6a8cbe6a-3595-4a09-a9ac-766edf0e857a
# ✅ Uploaded: Forbrugsforeningen_p26.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p27.json - source_file = Forbrugsforeningen.pdf, id = 955cdf65-abd4-4ff5-8c78-883862d54837
# ✅ Uploaded: Forbrugsforeningen_p27.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p28.json - source_file = Forbrugsforeningen.pdf, id = bc628530-3885-490e-a1f9-ad5f9227f319
# ✅ Uploaded: Forbrugsforeningen_p28.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p3.json - source_file = Forbrugsforeningen.pdf, id = 7077d397-4cba-4d95-a626-74e51b56a2a5
# ✅ Uploaded: Forbrugsforeningen_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p4.json - source_file = Forbrugsforeningen.pdf, id = bd9d5908-dff4-49a6-92f6-10c80b7df1bb
# ✅ Uploaded: Forbrugsforeningen_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p5.json - source_file = Forbrugsforeningen.pdf, id = bc45d8e0-1e42-4c8d-95ba-4f6b4edccecd
# ✅ Uploaded: Forbrugsforeningen_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p6.json - source_file = Forbrugsforeningen.pdf, id = 2231bdd2-cb50-4835-a2fb-2b56191de0b7
# ✅ Uploaded: Forbrugsforeningen_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p7.json - source_file = Forbrugsforeningen.pdf, id = 8c867a5a-23f9-4dbb-aff6-e83a2353267f
# ✅ Uploaded: Forbrugsforeningen_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p8.json - source_file = Forbrugsforeningen.pdf, id = 8212739f-3e97-412f-b646-9b714122e4a2
# ✅ Uploaded: Forbrugsforeningen_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Forbrugsforeningen_p9.json - source_file = Forbrugsforeningen.pdf, id = 1c734b94-296b-4486-b72f-e14fc36cd12b
# ✅ Uploaded: Forbrugsforeningen_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p1.json - source_file = Gastromé.pdf, id = 91bdf3e3-b588-4fc0-831d-76b810439bd0
# ✅ Uploaded: Gastromé_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p10.json - source_file = Gastromé.pdf, id = ece09e77-8d9f-4d6f-8bd9-f9e9ac79685d
# ✅ Uploaded: Gastromé_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p11.json - source_file = Gastromé.pdf, id = 8d320ba2-ab8b-4d8b-baa1-5617567c5170
# ✅ Uploaded: Gastromé_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p12.json - source_file = Gastromé.pdf, id = 29f4db30-b71c-4147-92bc-d1795c11952e
# ✅ Uploaded: Gastromé_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p13.json - source_file = Gastromé.pdf, id = b87366a9-de5e-4792-bc39-0b6e91e5ef8b
# ✅ Uploaded: Gastromé_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p14.json - source_file = Gastromé.pdf, id = 6a1b1450-97c5-4a9c-beff-f40e9e35668e
# ✅ Uploaded: Gastromé_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p15.json - source_file = Gastromé.pdf, id = 1f117471-8338-46ee-8471-f9fc672749d9
# ✅ Uploaded: Gastromé_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p16.json - source_file = Gastromé.pdf, id = f3d57622-5459-4ca8-9600-e2fa36ebc590
# ✅ Uploaded: Gastromé_p16.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p17.json - source_file = Gastromé.pdf, id = d149c41b-0532-4d2f-9b1e-6b0cf7bdb926
# ✅ Uploaded: Gastromé_p17.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p18.json - source_file = Gastromé.pdf, id = d257bb79-ebaf-4041-b31d-68627edad6f2
# ✅ Uploaded: Gastromé_p18.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p2.json - source_file = Gastromé.pdf, id = a14e9e3a-34aa-4924-96b0-3306c2308530
# ✅ Uploaded: Gastromé_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p3.json - source_file = Gastromé.pdf, id = d7d21a91-1940-4023-be60-7fc24418b760
# ✅ Uploaded: Gastromé_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p4.json - source_file = Gastromé.pdf, id = babe7651-063f-4aec-989f-bf16b2ef2357
# ✅ Uploaded: Gastromé_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p5.json - source_file = Gastromé.pdf, id = d219f249-a8a0-4289-b201-12c583dcc4e0
# ✅ Uploaded: Gastromé_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p6.json - source_file = Gastromé.pdf, id = 6b80796a-661a-421f-920d-7559b4bd6c60
# ✅ Uploaded: Gastromé_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p7.json - source_file = Gastromé.pdf, id = dc2ac5fc-b7cf-4d1d-b097-399600d39ed8
# ✅ Uploaded: Gastromé_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p8.json - source_file = Gastromé.pdf, id = 8261596d-0c16-4391-88bb-960861cb3448
# ✅ Uploaded: Gastromé_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Gastromé_p9.json - source_file = Gastromé.pdf, id = 1829aa0e-b8ef-497b-965e-9e8a7f46218e
# ✅ Uploaded: Gastromé_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p1.json - source_file = Gastrotools2.pdf, id = b58b4e66-11d8-437d-bbe3-821e09f90e01
# ✅ Uploaded: Gastrotools2_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p10.json - source_file = Gastrotools2.pdf, id = 077f57f9-fb1a-4b4e-9c29-d717bcb7468c
# ✅ Uploaded: Gastrotools2_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p100.json - source_file = Gastrotools2.pdf, id = f8d8188f-7233-479b-9404-a6a3d3944ca5
# ✅ Uploaded: Gastrotools2_p100.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p101.json - source_file = Gastrotools2.pdf, id = d6e376a8-2d19-4b78-a269-3fd9e1547ae9
# ✅ Uploaded: Gastrotools2_p101.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p102.json - source_file = Gastrotools2.pdf, id = 66afa971-8182-4431-9d64-465670d18071
# ✅ Uploaded: Gastrotools2_p102.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p103.json - source_file = Gastrotools2.pdf, id = 7a459809-af96-4b75-ad3b-718bbec1841d
# ✅ Uploaded: Gastrotools2_p103.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p104.json - source_file = Gastrotools2.pdf, id = c5659613-36db-40d6-abde-bdcf2e0aa9d9
# ✅ Uploaded: Gastrotools2_p104.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p105.json - source_file = Gastrotools2.pdf, id = 9dffa729-6c41-4db9-a8f9-ec53b80f1eee
# ✅ Uploaded: Gastrotools2_p105.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p106.json - source_file = Gastrotools2.pdf, id = 87bc196e-05ec-4770-9b6f-f93868e0943d
# ✅ Uploaded: Gastrotools2_p106.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p107.json - source_file = Gastrotools2.pdf, id = 29e0b441-fa1e-4a79-a574-c6622d412611
# ✅ Uploaded: Gastrotools2_p107.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p108.json - source_file = Gastrotools2.pdf, id = f92a6871-e6e7-41cb-ae93-c3193c8e96b7
# ✅ Uploaded: Gastrotools2_p108.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p109.json - source_file = Gastrotools2.pdf, id = 8cefc963-bc9f-46d6-af84-7f94ffaefe58
# ✅ Uploaded: Gastrotools2_p109.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p11.json - source_file = Gastrotools2.pdf, id = ae15207b-97ab-44c9-85ef-c42d67cfc82c
# ✅ Uploaded: Gastrotools2_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p110.json - source_file = Gastrotools2.pdf, id = be809e09-f2ed-4e1b-b73a-3b80486f5449
# ✅ Uploaded: Gastrotools2_p110.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p111.json - source_file = Gastrotools2.pdf, id = 39d8a422-4710-4f53-a2ae-b5783058c794
# ✅ Uploaded: Gastrotools2_p111.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p112.json - source_file = Gastrotools2.pdf, id = 8b6fb72c-5979-46f2-a344-0c9e54c723f2
# ✅ Uploaded: Gastrotools2_p112.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p113.json - source_file = Gastrotools2.pdf, id = cf2e8fe0-547f-4752-ab87-337a04a75952
# ✅ Uploaded: Gastrotools2_p113.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p114.json - source_file = Gastrotools2.pdf, id = 142fd223-18e2-4c3b-ae1f-0df750997d59
# ✅ Uploaded: Gastrotools2_p114.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p12.json - source_file = Gastrotools2.pdf, id = e74bf011-1ab5-4f67-95a8-02cbed272658
# ✅ Uploaded: Gastrotools2_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p13.json - source_file = Gastrotools2.pdf, id = 354787c4-eba7-4e26-9a42-a4987390cee2
# ✅ Uploaded: Gastrotools2_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p14.json - source_file = Gastrotools2.pdf, id = a95f4203-fcb9-4ef9-83f4-876548808b54
# ✅ Uploaded: Gastrotools2_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p15.json - source_file = Gastrotools2.pdf, id = b2b76b1e-3bb1-4f63-bf9b-167377a90a19
# ✅ Uploaded: Gastrotools2_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p16.json - source_file = Gastrotools2.pdf, id = 01db25be-2721-40dd-9c52-4964cec77a3e
# ✅ Uploaded: Gastrotools2_p16.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p17.json - source_file = Gastrotools2.pdf, id = 0b998572-a7a0-4ef5-b4a7-ae7c430a392f
# ✅ Uploaded: Gastrotools2_p17.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p18.json - source_file = Gastrotools2.pdf, id = 7d821ff9-47fd-4b16-a014-3d78d676cc42
# ✅ Uploaded: Gastrotools2_p18.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p19.json - source_file = Gastrotools2.pdf, id = 5b9d29bf-c0ac-4f2c-82d8-78c42c1c6acb
# ✅ Uploaded: Gastrotools2_p19.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p2.json - source_file = Gastrotools2.pdf, id = ace17d50-7604-4c7b-ab86-32887c820626
# ✅ Uploaded: Gastrotools2_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p20.json - source_file = Gastrotools2.pdf, id = 6be4b195-d807-45a7-b6f1-a072e29eed03
# ✅ Uploaded: Gastrotools2_p20.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p21.json - source_file = Gastrotools2.pdf, id = eac4a64d-762b-4725-b469-6412c532d47b
# ✅ Uploaded: Gastrotools2_p21.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p22.json - source_file = Gastrotools2.pdf, id = 83b7ead1-3b07-4236-9f6e-5cbe324ac01d
# ✅ Uploaded: Gastrotools2_p22.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p23.json - source_file = Gastrotools2.pdf, id = 4ea01a30-bf8f-406e-a726-ab33d64379a3
# ✅ Uploaded: Gastrotools2_p23.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p24.json - source_file = Gastrotools2.pdf, id = a6dd1b3b-1a90-45f1-9d7f-bb21e6bbb5c1
# ✅ Uploaded: Gastrotools2_p24.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p25.json - source_file = Gastrotools2.pdf, id = 1a5b17b7-0f05-43a8-bcdd-26ef70b37745
# ✅ Uploaded: Gastrotools2_p25.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p26.json - source_file = Gastrotools2.pdf, id = 42f75c58-3ada-48cb-a0a6-fe52d20367e7
# ✅ Uploaded: Gastrotools2_p26.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p27.json - source_file = Gastrotools2.pdf, id = 6acd7125-53a2-46a7-9c59-90d22c653306
# ✅ Uploaded: Gastrotools2_p27.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p28.json - source_file = Gastrotools2.pdf, id = 702243b8-32a2-4374-a718-de4f059a820d
# ✅ Uploaded: Gastrotools2_p28.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p29.json - source_file = Gastrotools2.pdf, id = e88d1f7e-1560-4298-abb1-cd3cfca92d5e
# ✅ Uploaded: Gastrotools2_p29.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p3.json - source_file = Gastrotools2.pdf, id = cae58f50-c654-44b7-9ad3-3c61ed6b7476
# ✅ Uploaded: Gastrotools2_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p30.json - source_file = Gastrotools2.pdf, id = c50b1f10-3606-4dd8-90cb-47d1a2eebd45
# ✅ Uploaded: Gastrotools2_p30.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p31.json - source_file = Gastrotools2.pdf, id = 9e268e92-46c3-4e7f-b449-ee1a86835c0f
# ✅ Uploaded: Gastrotools2_p31.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p32.json - source_file = Gastrotools2.pdf, id = 4defd255-7cbb-4f9f-b48e-f20ce75a9985
# ✅ Uploaded: Gastrotools2_p32.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p33.json - source_file = Gastrotools2.pdf, id = e3da5dfb-b85c-4c8d-99bc-8eeb38f47d2c
# ✅ Uploaded: Gastrotools2_p33.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p34.json - source_file = Gastrotools2.pdf, id = 34fff250-2693-4ce7-af2d-c1319c201812
# ✅ Uploaded: Gastrotools2_p34.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p35.json - source_file = Gastrotools2.pdf, id = 95e12347-5b30-49ec-b12d-b06756c8047f
# ✅ Uploaded: Gastrotools2_p35.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p36.json - source_file = Gastrotools2.pdf, id = 3ae1d2bc-319a-4336-b372-181dc8d916bc
# ✅ Uploaded: Gastrotools2_p36.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p37.json - source_file = Gastrotools2.pdf, id = a1cf6ecd-8891-40a1-ae97-a154ea7016b0
# ✅ Uploaded: Gastrotools2_p37.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p38.json - source_file = Gastrotools2.pdf, id = 7d41e6f1-8ad4-41d2-98df-d34f0b2f51fa
# ✅ Uploaded: Gastrotools2_p38.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p39.json - source_file = Gastrotools2.pdf, id = 3b3186a9-81c2-4b9e-8b8a-23cd836a36f2
# ✅ Uploaded: Gastrotools2_p39.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p4.json - source_file = Gastrotools2.pdf, id = 6df2aa68-6826-4a04-a2ff-8e676df1e36e
# ✅ Uploaded: Gastrotools2_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p40.json - source_file = Gastrotools2.pdf, id = 12c6a5fb-9e8b-4db4-a4c3-4680396f2308
# ✅ Uploaded: Gastrotools2_p40.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p41.json - source_file = Gastrotools2.pdf, id = 3797955a-f95a-4bc4-bcab-b13e918d02ad
# ✅ Uploaded: Gastrotools2_p41.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p42.json - source_file = Gastrotools2.pdf, id = 327d209a-8c30-4c81-8633-b7f789d0294b
# ✅ Uploaded: Gastrotools2_p42.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p43.json - source_file = Gastrotools2.pdf, id = ff8494b1-cfe0-4b73-b9d5-ce8984d3b062
# ✅ Uploaded: Gastrotools2_p43.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p44.json - source_file = Gastrotools2.pdf, id = e8683bb7-7833-47d4-993c-940210d536bf
# ✅ Uploaded: Gastrotools2_p44.json
# 🚀 Upload forsøg færdig
# 🔍 Gastrotools2_p45.json - source_file = Gastrotools2.pdf, id = f58906ce-732b-4091-b978-962ea44ea03a
# ...
# ✅ Uploaded: Tankesport_p46.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p47.json - source_file = Tankesport.pdf, id = 0dc1d2f5-d96f-49b5-ba34-0b8281d127c7
# ✅ Uploaded: Tankesport_p47.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p48.json - source_file = Tankesport.pdf, id = 1736a971-b741-43e6-bb74-05a871756a73
# ✅ Uploaded: Tankesport_p48.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p49.json - source_file = Tankesport.pdf, id = cb6f9663-9d50-40ef-ba96-82240eea1769
# ✅ Uploaded: Tankesport_p49.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p5.json - source_file = Tankesport.pdf, id = 71ed7531-05ad-41f8-991c-395ffbe8ff32
# ✅ Uploaded: Tankesport_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p50.json - source_file = Tankesport.pdf, id = 8ebd6d25-bd97-4cad-994f-ba48d93b9992
# ✅ Uploaded: Tankesport_p50.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p51.json - source_file = Tankesport.pdf, id = fb9bb4e3-d1e0-45dd-8769-68b88b417c36
# ✅ Uploaded: Tankesport_p51.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p52.json - source_file = Tankesport.pdf, id = df3b6e5b-01b2-4350-aeb2-3c44aa1b6b65
# ✅ Uploaded: Tankesport_p52.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p53.json - source_file = Tankesport.pdf, id = 1bac7d49-e27f-4d8f-ac89-dd83289ee7ea
# ✅ Uploaded: Tankesport_p53.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p54.json - source_file = Tankesport.pdf, id = 612be208-ee86-4d4d-9909-0b7cc25193be
# ✅ Uploaded: Tankesport_p54.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p55.json - source_file = Tankesport.pdf, id = d372ae35-850c-43b8-a534-df62c543d3c4
# ✅ Uploaded: Tankesport_p55.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p56.json - source_file = Tankesport.pdf, id = 48032c57-a049-4195-83ea-d7c1380ea709
# ✅ Uploaded: Tankesport_p56.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p57.json - source_file = Tankesport.pdf, id = a80801b5-c038-4f61-8471-8b75d62c99c7
# ✅ Uploaded: Tankesport_p57.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p58.json - source_file = Tankesport.pdf, id = 30fdaaed-8ecf-4cca-8f13-df10e84edd00
# ✅ Uploaded: Tankesport_p58.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p59.json - source_file = Tankesport.pdf, id = 5e900007-1500-4300-a54b-2501e66c64b5
# ✅ Uploaded: Tankesport_p59.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p6.json - source_file = Tankesport.pdf, id = 41dbd008-1dc3-4a3f-bded-e36e4faf5735
# ✅ Uploaded: Tankesport_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p60.json - source_file = Tankesport.pdf, id = ab793dd0-4d87-4221-9d4f-7358d8668bcb
# ✅ Uploaded: Tankesport_p60.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p61.json - source_file = Tankesport.pdf, id = 50c1bef4-2b6a-423d-94da-ff2a327c5b48
# ✅ Uploaded: Tankesport_p61.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p7.json - source_file = Tankesport.pdf, id = 48d37980-2996-49fd-970b-4000a9899028
# ✅ Uploaded: Tankesport_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p8.json - source_file = Tankesport.pdf, id = 3461524d-b533-49cb-abe1-7fbf086ca115
# ✅ Uploaded: Tankesport_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Tankesport_p9.json - source_file = Tankesport.pdf, id = fc7741c7-4279-4433-84f4-68a97a0f72dc
# ✅ Uploaded: Tankesport_p9.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p1.json - source_file = Wellvita.pdf, id = 5541a5ee-6ddb-4290-9a6d-6a11d0d86b41
# ✅ Uploaded: Wellvita_p1.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p10.json - source_file = Wellvita.pdf, id = 7bbfa0d5-e809-446f-9fb5-23cf9ab459ab
# ✅ Uploaded: Wellvita_p10.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p11.json - source_file = Wellvita.pdf, id = b6b4fb8a-77dd-44d5-8000-55bc16d5de4d
# ✅ Uploaded: Wellvita_p11.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p12.json - source_file = Wellvita.pdf, id = 15e1213f-ebd5-4b4a-88d7-2ee4aea5cb4f
# ✅ Uploaded: Wellvita_p12.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p13.json - source_file = Wellvita.pdf, id = 6c035377-8fed-4bda-bfd6-7f9869164ade
# ✅ Uploaded: Wellvita_p13.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p14.json - source_file = Wellvita.pdf, id = 8664199a-3858-4a7e-bcc2-877bc14ce403
# ✅ Uploaded: Wellvita_p14.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p15.json - source_file = Wellvita.pdf, id = a3761308-95e3-47fe-b0c8-96f2add6c2f0
# ✅ Uploaded: Wellvita_p15.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p16.json - source_file = Wellvita.pdf, id = e7aaa5d7-8ed1-4869-b0be-41eb94e5b808
# ✅ Uploaded: Wellvita_p16.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p17.json - source_file = Wellvita.pdf, id = 72ee2809-8e2d-4208-b328-1d7279bbb45e
# ✅ Uploaded: Wellvita_p17.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p18.json - source_file = Wellvita.pdf, id = 410ac0da-aa57-4111-b4ca-42c5f2a4618e
# ✅ Uploaded: Wellvita_p18.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p19.json - source_file = Wellvita.pdf, id = 61a4b360-2f9e-47cc-ae0f-dedb78cbea66
# ✅ Uploaded: Wellvita_p19.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p2.json - source_file = Wellvita.pdf, id = 941bab4b-911a-4688-8beb-ffbe28b69b1a
# ✅ Uploaded: Wellvita_p2.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p20.json - source_file = Wellvita.pdf, id = 012de5d6-53aa-4d05-96b5-d5a273bde166
# ✅ Uploaded: Wellvita_p20.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p21.json - source_file = Wellvita.pdf, id = 64aacc1f-f1ac-46e7-a479-100a8a824ef2
# ✅ Uploaded: Wellvita_p21.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p22.json - source_file = Wellvita.pdf, id = 7d786e84-4a49-4070-8e6d-994b0f13ecaf
# ✅ Uploaded: Wellvita_p22.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p23.json - source_file = Wellvita.pdf, id = 12fbb4f9-cd5c-4314-bccc-91a73ce440c3
# ✅ Uploaded: Wellvita_p23.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p24.json - source_file = Wellvita.pdf, id = 336b3be2-4e3e-4959-916c-d9d8150c42d2
# ✅ Uploaded: Wellvita_p24.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p25.json - source_file = Wellvita.pdf, id = 218add13-5c8a-4777-8212-d0c19a931644
# ✅ Uploaded: Wellvita_p25.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p26.json - source_file = Wellvita.pdf, id = 06044fa0-676b-469e-b50d-f72c6fc0d04b
# ✅ Uploaded: Wellvita_p26.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p27.json - source_file = Wellvita.pdf, id = 896dfb30-6127-4945-8235-bb6d5e9d7b0d
# ✅ Uploaded: Wellvita_p27.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p28.json - source_file = Wellvita.pdf, id = 4cc99a01-2528-4c81-80eb-7127f5fffa05
# ✅ Uploaded: Wellvita_p28.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p29.json - source_file = Wellvita.pdf, id = 93e4e5eb-4e42-4ebe-8ae0-9d0a3ed78f75
# ✅ Uploaded: Wellvita_p29.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p3.json - source_file = Wellvita.pdf, id = a19494c0-422c-4450-bf1b-85d5ca6763b1
# ✅ Uploaded: Wellvita_p3.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p30.json - source_file = Wellvita.pdf, id = 6a1f57e0-6d5f-4d9b-a69d-0ac0e900bfb8
# ✅ Uploaded: Wellvita_p30.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p31.json - source_file = Wellvita.pdf, id = d450ddfa-d759-4622-97bc-227d3e5aeafe
# ✅ Uploaded: Wellvita_p31.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p32.json - source_file = Wellvita.pdf, id = 1428d9ce-b090-4276-abe0-68e297789952
# ✅ Uploaded: Wellvita_p32.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p33.json - source_file = Wellvita.pdf, id = 5d04b368-7d29-431e-9b12-594f63881b01
# ✅ Uploaded: Wellvita_p33.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p34.json - source_file = Wellvita.pdf, id = ed351cbc-bc93-43a3-87b6-60a22d1b4568
# ✅ Uploaded: Wellvita_p34.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p35.json - source_file = Wellvita.pdf, id = b26e1baf-3a23-4126-861b-f96bf99fdcdf
# ✅ Uploaded: Wellvita_p35.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p36.json - source_file = Wellvita.pdf, id = ef6fb940-74bf-41bb-a818-05dd7b7dc545
# ✅ Uploaded: Wellvita_p36.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p37.json - source_file = Wellvita.pdf, id = 05261aee-46b7-4448-bc86-da075dcc0195
# ✅ Uploaded: Wellvita_p37.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p38.json - source_file = Wellvita.pdf, id = f4f65677-6370-456a-9d6c-3b651b6a7110
# ✅ Uploaded: Wellvita_p38.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p39.json - source_file = Wellvita.pdf, id = 73665c3e-07e9-4b4d-a065-3c813b4a9b83
# ✅ Uploaded: Wellvita_p39.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p4.json - source_file = Wellvita.pdf, id = 9cac73b6-c4e1-40da-b967-893ca1845461
# ✅ Uploaded: Wellvita_p4.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p40.json - source_file = Wellvita.pdf, id = 9f17cd11-b1c1-4eb8-8fb3-959266ef00a7
# ✅ Uploaded: Wellvita_p40.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p41.json - source_file = Wellvita.pdf, id = 06453f11-a8e0-4c48-a2ef-53545d2e0264
# ✅ Uploaded: Wellvita_p41.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p42.json - source_file = Wellvita.pdf, id = eec12354-c8b3-4fae-86dd-041509d14ddf
# ✅ Uploaded: Wellvita_p42.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p43.json - source_file = Wellvita.pdf, id = 69047449-0e0a-4fd4-8c9d-c786781c95dd
# ✅ Uploaded: Wellvita_p43.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p44.json - source_file = Wellvita.pdf, id = 5970f126-e16c-4d14-a783-2838f4d6542f
# ✅ Uploaded: Wellvita_p44.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p45.json - source_file = Wellvita.pdf, id = f2e1ad66-de25-4e81-bbfe-e41472b9a615
# ✅ Uploaded: Wellvita_p45.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p46.json - source_file = Wellvita.pdf, id = 7f7052b4-aa24-4570-aee3-bf82d826e5a2
# ✅ Uploaded: Wellvita_p46.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p47.json - source_file = Wellvita.pdf, id = 8064e8d2-5919-4e3d-a10d-8adb81491eb3
# ✅ Uploaded: Wellvita_p47.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p48.json - source_file = Wellvita.pdf, id = 0cedab19-2afb-48a4-9cd8-5a3fb3037d79
# ✅ Uploaded: Wellvita_p48.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p49.json - source_file = Wellvita.pdf, id = bd120e78-9dca-4d83-a673-863fed3b607b
# ✅ Uploaded: Wellvita_p49.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p5.json - source_file = Wellvita.pdf, id = 07c32b01-dec3-4f0a-8f05-23fe11734b27
# ✅ Uploaded: Wellvita_p5.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p50.json - source_file = Wellvita.pdf, id = 9880c98e-49cd-422a-8756-e3734b549619
# ✅ Uploaded: Wellvita_p50.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p51.json - source_file = Wellvita.pdf, id = ec779097-2fea-4097-942c-c314a6cb1c3f
# ✅ Uploaded: Wellvita_p51.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p52.json - source_file = Wellvita.pdf, id = 6e6f4337-f653-4317-897c-4fbec8ccee04
# ✅ Uploaded: Wellvita_p52.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p53.json - source_file = Wellvita.pdf, id = c83c9a5d-fa08-4c6e-a209-2d71e84a544c
# ✅ Uploaded: Wellvita_p53.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p54.json - source_file = Wellvita.pdf, id = 5e09ce89-010d-4ab2-9262-38dcf9692b68
# ✅ Uploaded: Wellvita_p54.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p55.json - source_file = Wellvita.pdf, id = 88ae14a0-2f66-4f3e-bef6-ae9b236b4494
# ✅ Uploaded: Wellvita_p55.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p56.json - source_file = Wellvita.pdf, id = 2e59d3d1-1a09-4ad8-a189-d682dc75089e
# ✅ Uploaded: Wellvita_p56.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p57.json - source_file = Wellvita.pdf, id = 6a2d8c03-051a-4183-bda2-e9a7f9ec1e7b
# ✅ Uploaded: Wellvita_p57.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p58.json - source_file = Wellvita.pdf, id = 26bd38ad-c55d-47bb-beed-6062c1ec1418
# ✅ Uploaded: Wellvita_p58.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p59.json - source_file = Wellvita.pdf, id = 6239c0d3-6e1d-4a64-8867-cbd6cfc34a06
# ✅ Uploaded: Wellvita_p59.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p6.json - source_file = Wellvita.pdf, id = 24c89120-3973-49e8-b30c-4bf5f39cd31d
# ✅ Uploaded: Wellvita_p6.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p60.json - source_file = Wellvita.pdf, id = d2fffd17-1826-4b73-a3c6-23544b0826ee
# ✅ Uploaded: Wellvita_p60.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p61.json - source_file = Wellvita.pdf, id = abbfb4e7-cd4f-42b6-81c2-00604dc46316
# ✅ Uploaded: Wellvita_p61.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p62.json - source_file = Wellvita.pdf, id = 8f71a4c3-7c28-485e-b118-896799760944
# ✅ Uploaded: Wellvita_p62.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p63.json - source_file = Wellvita.pdf, id = 461b6570-feaf-4a41-b21d-ea98ca0fa1ab
# ✅ Uploaded: Wellvita_p63.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p64.json - source_file = Wellvita.pdf, id = ffda880f-de0e-458a-8b97-01fd9842d235
# ✅ Uploaded: Wellvita_p64.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p65.json - source_file = Wellvita.pdf, id = 2c1586fd-b858-4f2f-8f9d-6a7c0cae1613
# ✅ Uploaded: Wellvita_p65.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p66.json - source_file = Wellvita.pdf, id = 7784ff14-4a34-47d2-b0bd-c2aa13e436f9
# ✅ Uploaded: Wellvita_p66.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p67.json - source_file = Wellvita.pdf, id = c6ada8c0-5f8b-40eb-a89b-0f1ab69d3a81
# ✅ Uploaded: Wellvita_p67.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p68.json - source_file = Wellvita.pdf, id = a65164f7-fdaf-405b-a786-f12c6eb2504b
# ✅ Uploaded: Wellvita_p68.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p69.json - source_file = Wellvita.pdf, id = 509088c2-3e6a-4673-b1ed-4129f498b99c
# ✅ Uploaded: Wellvita_p69.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p7.json - source_file = Wellvita.pdf, id = 52ced964-51c6-4ba1-9e75-01bdbcd8bda6
# ✅ Uploaded: Wellvita_p7.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p70.json - source_file = Wellvita.pdf, id = 42948db3-c63b-4846-8946-f93f93e2fe2b
# ✅ Uploaded: Wellvita_p70.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p71.json - source_file = Wellvita.pdf, id = 83ad81c1-f39a-4e37-89b2-e133663be7c9
# ✅ Uploaded: Wellvita_p71.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p72.json - source_file = Wellvita.pdf, id = 421cfc19-d8b7-425a-a19b-d95e93399755
# ✅ Uploaded: Wellvita_p72.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p73.json - source_file = Wellvita.pdf, id = 9aed053c-dcc2-4ad2-9bfc-964f8ca0c482
# ✅ Uploaded: Wellvita_p73.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p74.json - source_file = Wellvita.pdf, id = 91cb0e7e-50c4-485b-87c9-be9925d5b33a
# ✅ Uploaded: Wellvita_p74.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p75.json - source_file = Wellvita.pdf, id = c36ba0f9-889d-4281-b66a-8d00fb8b5374
# ✅ Uploaded: Wellvita_p75.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p76.json - source_file = Wellvita.pdf, id = be089183-3e6b-4b38-97d1-c7003a8a56ab
# ✅ Uploaded: Wellvita_p76.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p77.json - source_file = Wellvita.pdf, id = 28d72787-b7e8-40b2-9492-d47b16a8fae0
# ✅ Uploaded: Wellvita_p77.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p78.json - source_file = Wellvita.pdf, id = c3ffbce1-3b92-4c74-9cbf-5d361e814dbc
# ✅ Uploaded: Wellvita_p78.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p79.json - source_file = Wellvita.pdf, id = 575f3b7b-456b-4eeb-b50a-4f106a31146e
# ✅ Uploaded: Wellvita_p79.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p8.json - source_file = Wellvita.pdf, id = 16cb7aa2-f147-46dc-9828-593325df504e
# ✅ Uploaded: Wellvita_p8.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p80.json - source_file = Wellvita.pdf, id = 3296b297-928d-45af-9b98-632e651cd20c
# ✅ Uploaded: Wellvita_p80.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p81.json - source_file = Wellvita.pdf, id = 18ad89b9-1025-4e55-ba95-ae6519712f88
# ✅ Uploaded: Wellvita_p81.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p82.json - source_file = Wellvita.pdf, id = 947ab184-f8ca-4a63-b763-0f69bac4e178
# ✅ Uploaded: Wellvita_p82.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p83.json - source_file = Wellvita.pdf, id = 8a35d777-8e70-4380-a7cc-51d8f01afefd
# ✅ Uploaded: Wellvita_p83.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p84.json - source_file = Wellvita.pdf, id = 72c770a0-7a83-412c-b5dc-074e6fc3cabd
# ✅ Uploaded: Wellvita_p84.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p85.json - source_file = Wellvita.pdf, id = aae6c2a3-d2dd-41fd-828e-6d0d55785139
# ✅ Uploaded: Wellvita_p85.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p86.json - source_file = Wellvita.pdf, id = 47dfc703-6198-419f-981e-79467650a2ed
# ✅ Uploaded: Wellvita_p86.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p87.json - source_file = Wellvita.pdf, id = c5b0adb0-16b0-457b-96d5-24249a6be2d4
# ✅ Uploaded: Wellvita_p87.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p88.json - source_file = Wellvita.pdf, id = 49aacc05-d6e1-41b6-ae25-c2351a203686
# ✅ Uploaded: Wellvita_p88.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p89.json - source_file = Wellvita.pdf, id = 33c2e30f-1aed-4bd7-bb51-9f9b53f2c6f4
# ✅ Uploaded: Wellvita_p89.json
# 🚀 Upload forsøg færdig
# 🔍 Wellvita_p9.json - source_file = Wellvita.pdf, id = c3a45f52-2184-4527-82fe-2e25399b2aa7
# ✅ Uploaded: Wellvita_p9.json
# 🚀 Upload forsøg færdig
# done

# %%
import os
from azure.storage.blob import BlobServiceClient, ContentSettings

def upload_images_to_blob_storage(folder_path, connection_string, container_name):
    """
    Upload alle billedfiler i en mappe og dens undermapper til Azure Blob Storage.
    Bevarer relative sti i blob-navnene.
    dvs. blob beholder mappe struktur

    Args:
        folder_path (str): Rodmappe med billeder og undermapper.
        connection_string (str): Azure Blob Storage connection string.
        container_name (str): Navnet på Blob containeren.

    Returns:
        list: Liste over navne (blob-stier) på succesfuldt uploadede filer.
    """
    # allowed_extensions = ('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp') # hvis vi havde forskellige billedtyper
    uploaded_files = []

    blob_service_client = BlobServiceClient.from_connection_string(connection_string)
    container_client = blob_service_client.get_container_client(container_name)

    # Opret container hvis den ikke findes
    try:
        container_client.get_container_properties()
    except Exception:
        container_client.create_container()

    # Gennemgå alle filer i alle undermapper
    for root, _, files in os.walk(folder_path):
        print(folder_path)
        for filename in files:
            if filename.lower().endswith(".png"): # allowed_extensions
                file_path = os.path.join(root, filename)
                
                # Udregn relativ sti fra rodmappen til filen
                relative_path = os.path.relpath(file_path, folder_path).replace("\\", "/")
                
                blob_client = container_client.get_blob_client(relative_path)
                
                with open(file_path, "rb") as data:
                    blob_client.upload_blob(
                        data,
                        overwrite=True,
                        content_settings=ContentSettings(content_type=f"image/{filename.split('.')[-1]}")
                    )
                    uploaded_files.append(relative_path)
                    print(f"✅ Uploadet: {relative_path}")

    print("🎉 Alle billeder er uploadet.")
    return uploaded_files
upload_images_to_blob_storage(output_dir + "/images", "DefaultEndpointsProtocol=https;AccountName=ragstoragevcs;AccountKey=chAgt3B0KWv1ppQdj8cVra4Gh+WrgYJUPQGZtxsKZBxVIEi4OT7qWna0/87sPhe81PDh3ppDUKKv+AStu62kkw==;EndpointSuffix=core.windows.net","kb-images-test-upload")

# %%
upload_images_to_blob_storage(output_dir + "/images", "DefaultEndpointsProtocol=https;AccountName=ragstoragevcs;AccountKey=chAgt3B0KWv1ppQdj8cVra4Gh+WrgYJUPQGZtxsKZBxVIEi4OT7qWna0/87sPhe81PDh3ppDUKKv+AStu62kkw==;EndpointSuffix=core.windows.net","kb-images-test-upload")
